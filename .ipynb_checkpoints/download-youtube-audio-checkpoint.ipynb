# %%
import subprocess
import time

def download_audio_with_retries(youtube_url, output_path, max_retries=5):
    retry_count = 0
    while retry_count < max_retries:
        try:
            command = [
                'yt-dlp', '-x', '--audio-format', 'mp3', '-o', output_path, youtube_url
            ]
            subprocess.run(command, check=True)
            return output_path
        except subprocess.CalledProcessError as e:
            print(f"Attempt {retry_count + 1} failed: {str(e)}")
            time.sleep(5)  # wait 5 seconds before retrying
            retry_count += 1
    print("Failed to download after several retries.")
    return None

# URL for the YouTube video
youtube_url = 'https://www.youtube.com/watch?v=MXSTNZ6yKbc'

# Download audio file
output_path = '104-MXSTNZ6yKbc.mp3'
audio_path = download_audio_with_retries(youtube_url, output_path)
if audio_path:
    print(f'Audio downloaded successfully: {audio_path}')
else:
    print('Audio download failed.')
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VqP66pVRttw
# [youtube] VqP66pVRttw: Downloading webpage
# [youtube] VqP66pVRttw: Downloading ios player API JSON
# [youtube] VqP66pVRttw: Downloading player 1f8742dc
# [youtube] VqP66pVRttw: Downloading m3u8 information
# [info] VqP66pVRttw: Downloading 1 format(s): 140
# [download] Destination: 105-VqP66pVRttw.m4a
# [download] 100% of  233.18MiB in 00:01:04 at 3.64MiB/s
# [FixupM4a] Correcting container of "105-VqP66pVRttw.m4a"
# [ExtractAudio] Destination: 105-VqP66pVRttw.mp3
# Deleting original file 105-VqP66pVRttw.m4a (pass -k to keep)
# Audio downloaded successfully: 105-VqP66pVRttw.mp3
